# %%
print("ehllo")
# Out:
# ehllo

# %%
import pandas as pd

# %%
file = pd.read_csv("d1.csv")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7888\4040621763.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv("d1.csv")

# %%
file
# Out:
#        Unnamed: 0                                              TWEET  \
# 0               0  RT @robertoglezcano: @amazon  #Patents Show Fl...
# 1             NaN                                             Amazon
# 2               1  @FAME95FM1 Jamaicans make money with @Payoneer...
# 3               2  @CBSi Jamaicans make money with @Payoneer @Pay...
# 4               3  @Hitz92fm Jamaicans make money with @Payoneer ...
# ...           ...                                                ...
# 143277     861723  https://t.co/IsS8FGekqH: New Releases - Amazon...
# 143278        NaN                                             Amazon
# 143279     861864  RT @Google: With hands-free ordering from your...
# 143280     862071  Homegate with Lipton® Iced Tea from Walmart th...
# 143281        NaN                                            Walmart
#
#              STOCK        DATE   LAST_PRICE  1_DAY_RETURN  2_DAY_RETURN  \
# ...

# %%
file = file.drop(["DATE","LAST_PRICE", "PX_VOLUME",	"VOLATILITY_10D", 	"VOLATILITY_30D",	"TEXTBLOB_POLARITY",	"MENTION"], axis=1)

# %%
file
# Out:
#        Unnamed: 0                                              TWEET  \
# 0               0  RT @robertoglezcano: @amazon  #Patents Show Fl...
# 1             NaN                                             Amazon
# 2               1  @FAME95FM1 Jamaicans make money with @Payoneer...
# 3               2  @CBSi Jamaicans make money with @Payoneer @Pay...
# 4               3  @Hitz92fm Jamaicans make money with @Payoneer ...
# ...           ...                                                ...
# 143277     861723  https://t.co/IsS8FGekqH: New Releases - Amazon...
# 143278        NaN                                             Amazon
# 143279     861864  RT @Google: With hands-free ordering from your...
# 143280     862071  Homegate with Lipton® Iced Tea from Walmart th...
# 143281        NaN                                            Walmart
#
#              STOCK  1_DAY_RETURN  2_DAY_RETURN  3_DAY_RETURN  7_DAY_RETURN  \
# ...

# %%
file = file.dropna()

# %%
file
# Out:
#        Unnamed: 0                                              TWEET  \
# 2               1  @FAME95FM1 Jamaicans make money with @Payoneer...
# 3               2  @CBSi Jamaicans make money with @Payoneer @Pay...
# 4               3  @Hitz92fm Jamaicans make money with @Payoneer ...
# 11              7  RT @nikitakhara: Thank you, @Starbucks CEO for...
# 20             12  @gawker Jamaicans make money with @Payoneer @P...
# ...           ...                                                ...
# 143251     857260  RT @Microsoft: Announced at #MSIgnite: @Adobe,...
# 143252     857442  @KenDilanianNBC @Starbucks Great idea!!! \r\r\...
# 143259     858460  RT @BMW: Future proof technology, ensuring max...
# 143276     861648  RT @JanetCBrennan: OUT NOW!\r\r\r\r\r\r\nBarne...
# 143279     861864  RT @Google: With hands-free ordering from your...
#
#             STOCK  1_DAY_RETURN  2_DAY_RETURN  3_DAY_RETURN  7_DAY_RETURN  \
# ...

# %%
file.drop(["Unnamed: 0"], axis=1)
# Out:
#                                                     TWEET      STOCK  \
# 2       @FAME95FM1 Jamaicans make money with @Payoneer...     PayPal
# 3       @CBSi Jamaicans make money with @Payoneer @Pay...     PayPal
# 4       @Hitz92fm Jamaicans make money with @Payoneer ...     PayPal
# 11      RT @nikitakhara: Thank you, @Starbucks CEO for...  Starbucks
# 20      @gawker Jamaicans make money with @Payoneer @P...     PayPal
# ...                                                   ...        ...
# 143251  RT @Microsoft: Announced at #MSIgnite: @Adobe,...  Microsoft
# 143252  @KenDilanianNBC @Starbucks Great idea!!! \r\r\...  Starbucks
# 143259  RT @BMW: Future proof technology, ensuring max...        BMW
# 143276  RT @JanetCBrennan: OUT NOW!\r\r\r\r\r\r\nBarne...     Amazon
# 143279  RT @Google: With hands-free ordering from your...     Google
#
#         1_DAY_RETURN  2_DAY_RETURN  3_DAY_RETURN  7_DAY_RETURN LSTM_POLARITY
# ...

# %%
file = file.rename(columns={"SENTIMENT": "POLARITY"})

# %%
file
# Out:
#        Unnamed: 0                                              TWEET  \
# 2               1  @FAME95FM1 Jamaicans make money with @Payoneer...
# 3               2  @CBSi Jamaicans make money with @Payoneer @Pay...
# 4               3  @Hitz92fm Jamaicans make money with @Payoneer ...
# 11              7  RT @nikitakhara: Thank you, @Starbucks CEO for...
# 20             12  @gawker Jamaicans make money with @Payoneer @P...
# ...           ...                                                ...
# 143251     857260  RT @Microsoft: Announced at #MSIgnite: @Adobe,...
# 143252     857442  @KenDilanianNBC @Starbucks Great idea!!! \r\r\...
# 143259     858460  RT @BMW: Future proof technology, ensuring max...
# 143276     861648  RT @JanetCBrennan: OUT NOW!\r\r\r\r\r\r\nBarne...
# 143279     861864  RT @Google: With hands-free ordering from your...
#
#             STOCK  1_DAY_RETURN  2_DAY_RETURN  3_DAY_RETURN  7_DAY_RETURN  \
# ...
